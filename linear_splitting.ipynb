# %%
import pickle
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
from patsy import dmatrices
# %matplotlib inline

# %%
PICKLEDIR = "./pkls/"

# %%
def pickle_stuff(filename, data):
    with open(filename, 'w') as picklefile:
        pickle.dump(data, picklefile)

# %%
def unpickle(filename):
    with open(filename, 'r') as picklefile:
        old_data = pickle.load(picklefile)
    return old_data

# %%
def ols_domestic_constant(df):
    y, X = dmatrices('DomLifeGross ~ 1', data=df, return_type = 'dataframe')
    results, predicted = make_model(X, y)
    return X, y, results, predicted

# %%
def make_model(X, y):
    #print y.head(), X.head()
    model = sm.OLS(y,X)
    results = model.fit()
    print results.summary()
    #print "Parameters:", results.params
    print "R Squared", results.rsquared
    #print "Standard Errors", results.bse
    predicted = results.predict()
    #print "Predicted Values", predicted
    return results, predicted

# %%
def plot_domestic_constant(X, y, predicted):
    fig = plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    ax.yaxis.set_major_formatter(tkr.FuncFormatter(lambda x, pos: ('%.0f')%(x*1e-6)))
    ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x, pos: '%.0f'%x))

    plt.scatter(X["Intercept"], y, alpha=0.3)
    plt.scatter(X["Intercept"], predicted, color="red", alpha=0.6)
    plt.xlabel("Ones")
    plt.ylabel("Domestic Lifetime Gross")
    plt.show()

# %%
def plot_residuals(results):
    fig = plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    plt.hist(results.resid, bins=75, alpha=0.5)
    ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x, pos: ('%.0f')%(x*1e-6)))
    plt.ylabel("Count")
    plt.xlabel("Residual in Millions")
    plt.show()

# %%
def plot_domlifegross_forlifegross(X,y, predicted):
    fig = plt.figure(figsize=(10,10))
    ax = plt.subplot(111)
    ax.yaxis.set_major_formatter(tkr.FuncFormatter(lambda x, pos: ('%.0f')%(x*1e-6)))
    ax.xaxis.set_major_formatter(tkr.FuncFormatter(lambda x, pos: '%.0f'%(x*1e-6)))
    
    plt.scatter(x=X["ForLifeGross"], y=y["DomLifeGross"], alpha=0.3)
    plt.subplot(111)
    plt.plot(X["ForLifeGross"], predicted, color="red", alpha=0.6)
    plt.xlabel("Foreign Lifetime Gross")
    plt.ylabel("Domestic Lifetime Gross")
    plt.show()

# %%
def challenge_1(df):
    X, y, results, predicted = ols_domestic_constant(df)
    plot_domestic_constant(X, y, predicted)
    plot_residuals(results)
    print "Predicted:", predicted

# %%
def challenge_2(df):
    y, X = dmatrices('DomLifeGross ~ ForLifeGross', 
                     data=df, return_type = 'dataframe')
    results, predicted = make_model(X, y)
    plot_domlifegross_forlifegross(X,y, predicted)
    plot_residuals(results)

# %%
def challenge_3(df):
    df["OriginC"] = df["OriginC"].str.upper()
    y, X = dmatrices('DomLifeGross ~ OriginC', data=df, return_type = 'dataframe')
    #print y.head()
    #print X.head()
    results, predicted = make_model(X, y)
    #plot_domestic_origin(X,y, predicted)
    plot_residuals(results)

    y, X = dmatrices("DomLifeGross ~ OriginC + ForLifeGross", data=df, 
                     return_type = 'dataframe')
    results, predicted = make_model(X, y)
    plot_residuals(results)

# %% [markdown]
# **Prepare Dataframes**

# %%
movies = unpickle(PICKLEDIR + "cleanmovies.pkl")

# %%
df = pd.DataFrame.from_items(movies.items(), orient='index', 
                               columns=["OriginC", "Budget", "DomLifeGross",
                                       "ForLifeGross", "LtdRelDate", 
                                       "LtdOpenTh", "WRelDate", "WOpenTh", 
                                       "WidestTh", "Genres", "Awards"])
df.head()
# Out:
#                                                       OriginC   Budget  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      India     None
# (The Wedding Banquet, /movies/?id=weddingbanque...     Taiwan  1000000
# (Singham, /movies/?id=singham.htm)                      India     None
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     Hong Kong     None
# (Hermano, /movies/?id=hermano.htm)                      Italy     None
#
#                                                    DomLifeGross ForLifeGross  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      3108485         None
# (The Wedding Banquet, /movies/?id=weddingbanque...      6933459         None
# (Singham, /movies/?id=singham.htm)                       350864         None
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)          489600     42287160
# (Hermano, /movies/?id=hermano.htm)                        29864      1556003
#
#                                                    LtdRelDate LtdOpenTh  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....       None      None
# (The Wedding Banquet, /movies/?id=weddingbanque...       None      None
# (Singham, /movies/?id=singham.htm)                       None      None
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)          None      None
# (Hermano, /movies/?id=hermano.htm)                       None      None
#
#                                                           WRelDate WOpenTh  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....    July 15 2011     100
# (The Wedding Banquet, /movies/?id=weddingbanque...   August 6 1993       7
# (Singham, /movies/?id=singham.htm)                    July 22 2011      50
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)       April 2 2004       6
# (Hermano, /movies/?id=hermano.htm)                  August 24 2012      49
#
#                                                    WidestTh  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      100
# (The Wedding Banquet, /movies/?id=weddingbanque...      113
# (Singham, /movies/?id=singham.htm)                       50
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)          14
# (Hermano, /movies/?id=hermano.htm)                       49
#
#                                                                                                Genres  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                        [Foreign, Foreign Language]
# (The Wedding Banquet, /movies/?id=weddingbanque...  [Foreign, Foreign Language, Gay / Lesbian, Wed...
# (Singham, /movies/?id=singham.htm)                                        [Foreign, Foreign Language]
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     [Foreign / Action, Action - Martial Arts, Fore...
# (Hermano, /movies/?id=hermano.htm)                       [Foreign, Foreign Language, Sports - Soccer]
#
#                                                    Awards
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....  False
# (The Wedding Banquet, /movies/?id=weddingbanque...   True
# (Singham, /movies/?id=singham.htm)                  False
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     False
# (Hermano, /movies/?id=hermano.htm)                  False

# %%
df = df.fillna(value=np.nan)

# %%
df = df.fillna(value=np.nan)
df[["Budget","DomLifeGross","ForLifeGross", "LtdOpenTh", "WOpenTh", 
    "WidestTh"]] = df[["Budget", "DomLifeGross", "ForLifeGross", "LtdOpenTh", 
                       "WOpenTh", "WidestTh"]].astype(float)
df.head()
# Out:
#                                                       OriginC   Budget  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      India      NaN
# (The Wedding Banquet, /movies/?id=weddingbanque...     Taiwan  1000000
# (Singham, /movies/?id=singham.htm)                      India      NaN
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     Hong Kong      NaN
# (Hermano, /movies/?id=hermano.htm)                      Italy      NaN
#
#                                                     DomLifeGross  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....       3108485
# (The Wedding Banquet, /movies/?id=weddingbanque...       6933459
# (Singham, /movies/?id=singham.htm)                        350864
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           489600
# (Hermano, /movies/?id=hermano.htm)                         29864
#
#                                                     ForLifeGross LtdRelDate  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....           NaN        NaN
# (The Wedding Banquet, /movies/?id=weddingbanque...           NaN        NaN
# (Singham, /movies/?id=singham.htm)                           NaN        NaN
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)         42287160        NaN
# (Hermano, /movies/?id=hermano.htm)                       1556003        NaN
#
#                                                     LtdOpenTh        WRelDate  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....        NaN    July 15 2011
# (The Wedding Banquet, /movies/?id=weddingbanque...        NaN   August 6 1993
# (Singham, /movies/?id=singham.htm)                        NaN    July 22 2011
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           NaN    April 2 2004
# (Hermano, /movies/?id=hermano.htm)                        NaN  August 24 2012
#
#                                                     WOpenTh  WidestTh  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      100       100
# (The Wedding Banquet, /movies/?id=weddingbanque...        7       113
# (Singham, /movies/?id=singham.htm)                       50        50
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           6        14
# (Hermano, /movies/?id=hermano.htm)                       49        49
#
#                                                                                                Genres  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                        [Foreign, Foreign Language]
# (The Wedding Banquet, /movies/?id=weddingbanque...  [Foreign, Foreign Language, Gay / Lesbian, Wed...
# (Singham, /movies/?id=singham.htm)                                        [Foreign, Foreign Language]
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     [Foreign / Action, Action - Martial Arts, Fore...
# (Hermano, /movies/?id=hermano.htm)                       [Foreign, Foreign Language, Sports - Soccer]
#
#                                                    Awards
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....  False
# (The Wedding Banquet, /movies/?id=weddingbanque...   True
# (Singham, /movies/?id=singham.htm)                  False
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     False
# (Hermano, /movies/?id=hermano.htm)                  False

# %%
s = pd.Series(df["Genres"])
d_f = pd.get_dummies(s.apply(pd.Series).stack()).sum(level=0)
d_f.head()
# Out:
#                                                     3D  Action  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....   0       0
# (The Wedding Banquet, /movies/?id=weddingbanque...   0       0
# (Singham, /movies/?id=singham.htm)                   0       0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)      0       0
# (Hermano, /movies/?id=hermano.htm)                   0       0
#
#                                                     Action - Martial Arts  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                      0
# (The Wedding Banquet, /movies/?id=weddingbanque...                      0
# (Singham, /movies/?id=singham.htm)                                      0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                         1
# (Hermano, /movies/?id=hermano.htm)                                      0
#
#                                                     Action - Wire-Fu  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                 0
# (The Wedding Banquet, /movies/?id=weddingbanque...                 0
# (Singham, /movies/?id=singham.htm)                                 0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                    0
# (Hermano, /movies/?id=hermano.htm)                                 0
#
#                                                     Action Comedy  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....              0
# (The Wedding Banquet, /movies/?id=weddingbanque...              0
# (Singham, /movies/?id=singham.htm)                              0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                 0
# (Hermano, /movies/?id=hermano.htm)                              0
#
#                                                     Action Heroine  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....               0
# (The Wedding Banquet, /movies/?id=weddingbanque...               0
# (Singham, /movies/?id=singham.htm)                               0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                  0
# (Hermano, /movies/?id=hermano.htm)                               0
#
#                                                     Action Remake  Animation  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....              0          0
# (The Wedding Banquet, /movies/?id=weddingbanque...              0          0
# (Singham, /movies/?id=singham.htm)                              0          0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                 0          0
# (Hermano, /movies/?id=hermano.htm)                              0          0
#
#                                                     Animation - Anime  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                  0
# (The Wedding Banquet, /movies/?id=weddingbanque...                  0
# (Singham, /movies/?id=singham.htm)                                  0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                     0
# (Hermano, /movies/?id=hermano.htm)                                  0
#
#                                                     Animation - Computer  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                     0
# (The Wedding Banquet, /movies/?id=weddingbanque...                     0
# (Singham, /movies/?id=singham.htm)                                     0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                        0
# (Hermano, /movies/?id=hermano.htm)                                     0
#
#                                                      ...    Unknown  Vampire  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....   ...          0        0
# (The Wedding Banquet, /movies/?id=weddingbanque...   ...          0        0
# (Singham, /movies/?id=singham.htm)                   ...          0        0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)      ...          0        0
# (Hermano, /movies/?id=hermano.htm)                   ...          0        0
#
#                                                     Virtual Reality  War  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                0    0
# (The Wedding Banquet, /movies/?id=weddingbanque...                0    0
# (Singham, /movies/?id=singham.htm)                                0    0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                   0    0
# (Hermano, /movies/?id=hermano.htm)                                0    0
#
#                                                     War - World War 2  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                  0
# (The Wedding Banquet, /movies/?id=weddingbanque...                  0
# (Singham, /movies/?id=singham.htm)                                  0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                     0
# (Hermano, /movies/?id=hermano.htm)                                  0
#
#                                                     War - World War I  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....                  0
# (The Wedding Banquet, /movies/?id=weddingbanque...                  0
# (Singham, /movies/?id=singham.htm)                                  0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)                     0
# (Hermano, /movies/?id=hermano.htm)                                  0
#
#                                                     Wedding  Werewolf  Witch  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....        0         0      0
# (The Wedding Banquet, /movies/?id=weddingbanque...        1         0      0
# (Singham, /movies/?id=singham.htm)                        0         0      0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           0         0      0
# (Hermano, /movies/?id=hermano.htm)                        0         0      0
#
#                                                     Zombie
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....       0
# (The Wedding Banquet, /movies/?id=weddingbanque...       0
# (Singham, /movies/?id=singham.htm)                       0
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)          0
# (Hermano, /movies/?id=hermano.htm)                       0
#
# [5 rows x 101 columns]

# %% [markdown]
# **Note:**
# The drop throws an error if run more than once.

# %%
#df = df.drop("Genres", 1)

# %%
df.head()
# Out:
#                                                       OriginC   Budget  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      INDIA      NaN
# (The Wedding Banquet, /movies/?id=weddingbanque...     TAIWAN  1000000
# (Singham, /movies/?id=singham.htm)                      INDIA      NaN
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)     HONG KONG      NaN
# (Hermano, /movies/?id=hermano.htm)                      ITALY      NaN
#
#                                                     DomLifeGross  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....       3108485
# (The Wedding Banquet, /movies/?id=weddingbanque...       6933459
# (Singham, /movies/?id=singham.htm)                        350864
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           489600
# (Hermano, /movies/?id=hermano.htm)                         29864
#
#                                                     ForLifeGross LtdRelDate  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....           NaN        NaN
# (The Wedding Banquet, /movies/?id=weddingbanque...           NaN        NaN
# (Singham, /movies/?id=singham.htm)                           NaN        NaN
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)         42287160        NaN
# (Hermano, /movies/?id=hermano.htm)                       1556003        NaN
#
#                                                     LtdOpenTh        WRelDate  \
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....        NaN    July 15 2011
# (The Wedding Banquet, /movies/?id=weddingbanque...        NaN   August 6 1993
# (Singham, /movies/?id=singham.htm)                        NaN    July 22 2011
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           NaN    April 2 2004
# (Hermano, /movies/?id=hermano.htm)                        NaN  August 24 2012
#
#                                                     WOpenTh  WidestTh Awards
# (Zindagi Na Milegi Dobara, /movies/?id=zindagi....      100       100  False
# (The Wedding Banquet, /movies/?id=weddingbanque...        7       113   True
# (Singham, /movies/?id=singham.htm)                       50        50  False
# (Shaolin Soccer, /movies/?id=shaolinsoccer.htm)           6        14  False
# (Hermano, /movies/?id=hermano.htm)                       49        49  False

# %% [markdown]
# **Challenge 1**
# Build a linear model that uses only a constant term (a column of ones) to predict a continuous outcome (like domestic total gross).

# %%
challenge_1(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DomLifeGross   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                      -inf
# Date:                Sun, 12 Jul 2015   Prob (F-statistic):                nan
# Time:                        23:22:48   Log-Likelihood:                -25174.
# No. Observations:                1500   AIC:                         5.035e+04
# Df Residuals:                    1499   BIC:                         5.036e+04
# Df Model:                           0
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept   1.224e+06   1.21e+05     10.076      0.000      9.86e+05  1.46e+06
# ==============================================================================
# Omnibus:                     3097.060   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          9269840.892
# Skew:                          16.627   Prob(JB):                         0.00
# Kurtosis:                     386.682   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R Squared -1.55431223448e-15
# Predicted: [ 1224124.936  1224124.936  1224124.936 ...,  1224124.936  1224124.936
#   1224124.936]

# %% [markdown]
# How can you interpret the results of this model? What does it predict? Make a plot of predictions against actual outcome. Make a histogram of residuals. How are the residuals distributed?

# %% [markdown]
# The results of this model show that the Domestic Lifetime Gross of these movies cannot be predicted by a single constant value. This model predicts that all movies will gross 1.2 million dollars, when in reality, the totals vary widely. This is seen in both the plot of both data and predictions and in the fact that the R^2 value is 0. The residuals are mainly seen at zero, with a steep drop off and then occasional values up past 120 million.

# %% [markdown]
# **Challenge 2**
# Repeat the process of challenge one, but also add one continuous (numeric) predictor variable. Also add plots of model prediction against your feature variable and residuals against feature variable.

# %%
challenge_2(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DomLifeGross   R-squared:                       0.159
# Model:                            OLS   Adj. R-squared:                  0.158
# Method:                 Least Squares   F-statistic:                     135.6
# Date:                Sun, 12 Jul 2015   Prob (F-statistic):           8.00e-29
# Time:                        23:22:49   Log-Likelihood:                -12200.
# No. Observations:                 717   AIC:                         2.440e+04
# Df Residuals:                     715   BIC:                         2.441e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Intercept      3.93e+05   2.48e+05      1.587      0.113     -9.32e+04  8.79e+05
# ForLifeGross     0.0982      0.008     11.646      0.000         0.082     0.115
# ==============================================================================
# Omnibus:                     1341.523   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1692087.608
# Skew:                          12.705   Prob(JB):                         0.00
# Kurtosis:                     239.629   Cond. No.                     3.28e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.28e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# R Squared 0.159441385432

# %% [markdown]
# How can you interpret what's happening in the model?

# %% [markdown]
# This model is attempting to find a linear relationship between a film'ss Foreign Lifetime Gross and its Domestic Lifetime Gross. However, this relationship is either not very strong or is non-linear, since the prediction line does not appear to be a good fit and the R^2 value is still quite low. The residuals are slightly less concentrated at zero now, and are beginning to look a little bit like a bell curve.

# %% [markdown]
# **Challenge 3**
# Repeat the process of challenge 1, but add a categorical feature (like genre). You'll have to convert a column of text into a number of numerical columns ("dummy variables").

# %%
challenge_3(df)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           DomLifeGross   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.024
# Method:                 Least Squares   F-statistic:                     1.403
# Date:                Sun, 12 Jul 2015   Prob (F-statistic):             0.0121
# Time:                        23:37:39   Log-Likelihood:                -22467.
# No. Observations:                1338   AIC:                         4.510e+04
# Df Residuals:                    1255   BIC:                         4.553e+04
# Df Model:                          82
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                
# OriginC[T.PERU]                              1.995e+05   7.65e+06      0.026      0.979     -1.48e+07  1.52e+07
# OriginC[T.PHILIPPINES]                       2.341e+05   6.62e+06      0.035      0.972     -1.28e+07  1.32e+07
# OriginC[T.POLAND]                           -7.158e+05   6.62e+06     -0.108      0.914     -1.37e+07  1.23e+07
# OriginC[T.PORTUGAL]                          2.797e+05   6.62e+06      0.042      0.966     -1.27e+07  1.33e+07
# OriginC[T.ROMANIA]                           1.828e+05   5.92e+06      0.031      0.975     -1.14e+07  1.18e+07
# OriginC[T.RUSSIA]                             2.04e+05   5.84e+06      0.035      0.972     -1.13e+07  1.17e+07
# OriginC[T.SENEGAL]                           3.773e+05   7.65e+06      0.049      0.961     -1.46e+07  1.54e+07
# OriginC[T.SINGAPORE]                         8.109e+04   7.65e+06      0.011      0.992     -1.49e+07  1.51e+07
# OriginC[T.SOUTH AFRICA]                         0.0004      0.194      0.002      0.998        -0.381     0.382
# OriginC[T.SOUTH KOREA]                      -2.998e+06   5.51e+06     -0.544      0.586     -1.38e+07  7.82e+06
# OriginC[T.SPAIN]                            -2.482e+05   5.51e+06     -0.045      0.964     -1.11e+07  1.06e+07
# OriginC[T.SWEDEN]                           -1.065e+06   5.65e+06     -0.188      0.851     -1.22e+07     1e+07
# OriginC[T.SWITZERLAND]                      -3.842e+06   6.25e+06     -0.615      0.539     -1.61e+07  8.43e+06
# OriginC[T.TAIWAN]                            3.845e+07   6.25e+06      6.153      0.000      2.62e+07  5.07e+07
# OriginC[T.THAILAND]                          1.474e+06   5.78e+06      0.255      0.799     -9.88e+06  1.28e+07
# OriginC[T.THE DEMOCRATIC REPUBLIC OF CONGO] -3.643e-11   2.81e-10     -0.130      0.897     -5.88e-10  5.15e-10
# OriginC[T.THE NETHERLANDS]                  -2.039e-10   1.66e-09     -0.123      0.902     -3.46e-09  3.05e-09
# OriginC[T.TURKEY]                           -2.429e+05   5.92e+06     -0.041      0.967     -1.19e+07  1.14e+07
# OriginC[T.UK]                                1.155e+05   6.05e+06      0.019      0.985     -1.18e+07   1.2e+07
# OriginC[T.UKRAINE]                                   0          0        nan        nan             0         0
# OriginC[T.USA]                              -6.644e+05   5.78e+06     -0.115      0.909      -1.2e+07  1.07e+07
# OriginC[T.VENEZUELA]                          2.55e+05   7.65e+06      0.033      0.973     -1.48e+07  1.53e+07
# OriginC[T.VIETNAM]                           2.236e+05   7.65e+06      0.029      0.977     -1.48e+07  1.52e+07
# OriginC[T.YUGOSLAVIA]                                0          0        nan        nan             0         0
# ForLifeGross                                    0.1558      0.011     14.768      0.000         0.135     0.177
# ==============================================================================
# Omnibus:                      755.328   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           236631.207
# Skew:                           4.822   Prob(JB):                         0.00
# Kurtosis:                      94.978   Cond. No.                     1.71e+23
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.36e-29. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# R Squared 0.414958721394

# %% [markdown]
# How can you interpret what's happening in the model?

# %% [markdown]
# The first half is attempting to find a linear fit between country of origin and domestic lifetime gross, but according to the R^2 value, the fit is even worse than between foreign lifetime gross and domestic lifetime gross. The second half is attemting a fit with both foreign lifetime gross and country of origin to predict domestic lifetime gross. This seems to be the best so far, but is still not exactly good.
