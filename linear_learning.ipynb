# %%
import scipy
import numpy as np
import matplotlib.pyplot as plt
#import statsmodels.api as sm
import seaborn as sns
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn import linear_model

# %matplotlib inline
sns.set(style="whitegrid", color_codes=True)

# %% [markdown]
# **Challenge 1**
# Generate (fake) data that is linearly related to `log(x)`. You are making this model up. It is of the form `B0 + B1*log(x) + epsilon`. (You are making up the parameters.) Simulate some data from this model. Then fit two models to it:
# quadratic (second degree polynomial)
# logarithmic (`log(x)`)

# %%
fx = range(1, 201)
fy = [8*np.log(x) + 27 for x in fx]
print fx[:5], fy[:5]
# Out:
# [1, 2, 3, 4, 5] [27.0, 32.545177444479563, 35.78889830934488, 38.090354888959126, 39.875503299472804]

# %%
p = np.polyfit(fx, fy, 2)
p
# Out:
# array([ -9.37299782e-04,   3.05304834e-01,   4.34373602e+01])

# %%
def plot_fits(fx, fy, p):
    yfit = np.polyval(p,fx)

    plt.figure()
    plt.plot(fx,fy, label='data', color="green")
    plt.plot(fx,yfit, label='fit', color="blue")
    plt.plot(fx,yfit-fy, label='var', color="red")
    plt.show()

# %%
plot_fits(fx, fy, p)

# %%
p1 = np.polyfit(np.log(fx), fy, 2).tolist()
p1
# Out:
# [-6.38355095786675e-15, 8.000000000000028, 27.0]

# %%
plot_fits(np.log(fx),fy,p1)

# %% [markdown]
# **Challenge 2**
# Generate (fake) data from a model of the form `B0 + B1*x + B2*x^2 + epsilon`. (You are making up the parameters.)
# Split the data into a training and test set.
# Fit a model to your training set. Calculate mean squared error on your training set. Then calculate it on your test set.
# (You could use sklearn.metrics.mean_squared_error.)

# %%
fx2 = fx
fy2 = [14 + 6*x + 22*(x**2) for x in fx2]
print fx2[:5], fy2[:5]
# Out:
# [1, 2, 3, 4, 5] [42, 114, 230, 390, 594]

# %%
X_train, X_test, y_train, y_test = train_test_split(fx2, fy2, test_size=0.25, random_state=2)
print X_train[:5], y_train[:5]
# Out:
# [160 101  12 188  25] [564174 225042   3254 778710  13914]

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-d375745ae55d> in <module>()
#       1 regr = linear_model.LinearRegression()
# ----> 2 regr.fit(X_train, y_train)
#
# /usr/lib/python2.7/dist-packages/sklearn/linear_model/base.pyc in fit(self, X, y, n_jobs)
#     361
#     362         X, y, X_mean, y_mean, X_std = self._center_data(
# --> 363             X, y, self.fit_intercept, self.normalize, self.copy_X)
#     364
#     365         if sp.issparse(X):
#
# /usr/lib/python2.7/dist-packages/sklearn/linear_model/base.pyc in center_data(X, y, fit_intercept, normalize, copy, sample_weight)
#     101                 X /= X_std
#     102             else:
# --> 103                 X_std = np.ones(X.shape[1])
#     104         if no_sample_weight:
#     105             y_mean = y.mean(axis=0)
#
# IndexError: tuple index out of range

# %% [markdown]
# **Challenge 3**
# For the data from two (above), try polynomial fits from 0th (just constant) to 7th order (highest term x^7). Over the x axis of model degree (8 points), plot:
#  * training error
#  * test error
#  * R squared
#  * AIC

# %%
tr_ers = []
ts_ers = []
r_sqs = []
aics = []
deg = range(8)
for m in deg:
    X_train, X_test, y_train, y_test = train_test_split(fx2, fy2, test_size=0.25, random_state=2)
    tr_ers.append(tr_er)
    ts_ers.append(ts_er)
    r_sqs.append(rsq)
    aics.append(aic)

# %% [markdown]
# **Challenge 4**
# For the data from two (above), fit a model to only the first 5 of your data points (m=5). Then to first 10 (m=10). Then to first 15 (m=15). In this manner, keep fitting until you fit your entire training set. For each step, calculate the training error and the test error. Plot both (in the same plot) over m. This is called a learning curve.

# %%
tr_ers = []
ts_ers = []
ms = range(5, len(fx2), 5)
for m in ms:
    X_train = fx2[:m]
    X_test = fx2[m:]
    y_train = fy2[:m]
    y_test = fy2[m:]
    tr_ers.append(tr_er)
    ts_ers.append(ts_er)
    sns.plt.plot(tr_er, m)
    sns.plt.plot(ts_er, m)

sns.plt.show()
